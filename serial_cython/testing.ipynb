# %%
# Import required libraries.
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# + $\textbf{Testing With Command:}$ ```python run_lebwohl_lasher_s_cython.py 500 50 0.5 0```

# %% [markdown]
# $\textbf{1. Ensure Correct Plots Are Produced}$

# %%
def plot_data(data):
    """
    Plots energy and order parameter against Monte Carlo step.

    Parameters
    ----------
    data : pd.DataFrame
        The data from the Lebwohl-Lasher simulation.
    """

    # Plot energy and order parameter against Monte Carlo step.
    fig, ax = plt.subplots(1, 2, figsize=(12, 4))

    ax[0].plot(data.index, data["Energy"])
    ax[1].plot(data.index, data["Order"])

    ax[0].set_title("Reduced Temperature = 0.5")
    ax[0].set_xlabel("Monte Carlo Step")
    ax[0].set_ylabel("Reduced Energy")

    ax[1].set_title("Reduced Temperature = 0.5")
    ax[1].set_xlabel("Monte Carlo Step")
    ax[1].set_ylabel("Order Parameter")

    fig.tight_layout()
    plt.show()

# %% [markdown]
# $\textbf{1.1 Base Version}$
#
# + ```lebwohl_lasher_s_cython.py Version: Commit - 056be5e74a2735b1e6d6625e11b9deed38f00b10```

# %%
# Read in the output data.
data_001 = pd.DataFrame(np.loadtxt("output_logs/output_normal_056be5e74a2735b1e6d6625e11b9deed38f00b10.txt", 
                                   dtype=np.float64, skiprows=9), columns=["MCS", "Ratio", "Energy", "Order"]).set_index("MCS")

print(data_001.head().to_markdown())
# Out:
# |   MCS |   Ratio |   Energy |   Order |
# |------:|--------:|---------:|--------:|
# |     0 |  0.5    | -2467.7  |  0.261  |
# |     1 |  0.6832 | -3677.58 |  0.2562 |
# |     2 |  0.6192 | -4412.91 |  0.2588 |
# |     3 |  0.6056 | -4953.69 |  0.2583 |
# |     4 |  0.5664 | -5407.14 |  0.2553 |

# %%
# Plot the data.
plot_data(data_001)

# %% [markdown]
# $\textbf{1.2 Accelerated Function:}$ ```cell_energy```
#
# + ```run_lebwohl_lasher_s_cython.py Version: Commit - a483c7babd1bed483506d98443018aff8e5543b6```

# %%
# Read in the output data.
data_002 = pd.DataFrame(np.loadtxt("output_logs/output_normal_a483c7babd1bed483506d98443018aff8e5543b6.txt", 
                                   dtype=np.float64, skiprows=9), columns=["MCS", "Ratio", "Energy", "Order"]).set_index("MCS")

print(data_002.head().to_markdown())
# Out:
# |   MCS |   Ratio |   Energy |   Order |
# |------:|--------:|---------:|--------:|
# |     0 |  0.5    | -2628.88 |  0.256  |
# |     1 |  0.6784 | -3761.63 |  0.2617 |
# |     2 |  0.6228 | -4543.43 |  0.2726 |
# |     3 |  0.6052 | -5125.61 |  0.2764 |
# |     4 |  0.5496 | -5507.58 |  0.2768 |

# %%
# Plot the data.
plot_data(data_002)

# %% [markdown]
# $\textbf{1.3 Accelerated Function:}$ ```total_energy```
#
# + ```run_lebwohl_lasher_s_cython.py Version: Commit - a13774b66bf82e35d6b38bb6fd737ecbbc2fa16d```

# %%
# Read in the output data.
data_003 = pd.DataFrame(np.loadtxt("output_logs/output_normal_a13774b66bf82e35d6b38bb6fd737ecbbc2fa16d.txt", 
                                   dtype=np.float64, skiprows=9), columns=["MCS", "Ratio", "Energy", "Order"]).set_index("MCS")

print(data_003.head().to_markdown())
# Out:
# |   MCS |   Ratio |   Energy |   Order |
# |------:|--------:|---------:|--------:|
# |     0 |  0.5    | -2356.14 |  0.2678 |
# |     1 |  0.6844 | -3535.7  |  0.2628 |
# |     2 |  0.634  | -4367.45 |  0.2634 |
# |     3 |  0.5872 | -4937.9  |  0.2581 |
# |     4 |  0.5708 | -5480.94 |  0.2699 |

# %%
# Plot the data.
plot_data(data_003)

# %% [markdown]
# $\textbf{1.4 Accelerated Function:}$ ```calculate_order```
#
# + ```run_lebwohl_lasher_s_cython.py Version: Commit - 43ca69be37da6a969c9585b9dc5b5cbb85460c02```

# %%
# Read in the output data.
data_004 = pd.DataFrame(np.loadtxt("output_logs/output_normal_43ca69be37da6a969c9585b9dc5b5cbb85460c02.txt", 
                                   dtype=np.float64, skiprows=9), columns=["MCS", "Ratio", "Energy", "Order"]).set_index("MCS")

print(data_004.head().to_markdown())
# Out:
# |   MCS |   Ratio |   Energy |   Order |
# |------:|--------:|---------:|--------:|
# |     0 |  0.5    | -2561.73 |  0.2679 |
# |     1 |  0.6872 | -3782.72 |  0.2746 |
# |     2 |  0.626  | -4503.31 |  0.277  |
# |     3 |  0.5916 | -5024.94 |  0.2796 |
# |     4 |  0.5472 | -5402.52 |  0.2863 |

# %%
# Plot the data.
plot_data(data_004)

# %% [markdown]
# $\textbf{1.5 Accelerated Function:}$ ```monte_carlo_step```
#
# + ```run_lebwohl_lasher_s_cython.py Version: Commit - c8be37f204a23e5482934ec4a729b0c58c9c9e5d```

# %%
# Read in the output data.
data_005 = pd.DataFrame(np.loadtxt("output_logs/output_normal_c8be37f204a23e5482934ec4a729b0c58c9c9e5d.txt", 
                                   dtype=np.float64, skiprows=9), columns=["MCS", "Ratio", "Energy", "Order"]).set_index("MCS")

print(data_005.head().to_markdown())
# Out:
# |   MCS |   Ratio |   Energy |   Order |
# |------:|--------:|---------:|--------:|
# |     0 |  0.5    | -2439.05 |  0.2654 |
# |     1 |  0.674  | -3591.27 |  0.2591 |
# |     2 |  0.6256 | -4471.15 |  0.2571 |
# |     3 |  0.5924 | -5063.07 |  0.2612 |
# |     4 |  0.5504 | -5490.05 |  0.2682 |

# %%
# Plot the data.
plot_data(data_005)

# %% [markdown]
# $\textbf{2. Check Output Values Are Consistent}$
#
# + $\text{Test if the output logs across versions of the code are the same.}$
# + $\text{This is done through performing a simulation where the random seed is to 42.}$
#
# - ```-> np.random.seed(42)```

# %% [markdown]
# $\textbf{2.1 Base Version}$
#
# + ```lebwohl_lasher_s_cython.py Version: Commit - 056be5e74a2735b1e6d6625e11b9deed38f00b10```

# %%
# Read in the data.
data_compare_001 = pd.DataFrame(np.loadtxt("output_logs/output_seed_42_056be5e74a2735b1e6d6625e11b9deed38f00b10.txt", 
                                             dtype=np.float64, skiprows=9), columns=["MCS", "Ratio", "Energy", "Order"]).set_index("MCS")

print(data_compare_001.head().to_markdown())
# Out:
# |   MCS |   Ratio |   Energy |   Order |
# |------:|--------:|---------:|--------:|
# |     0 |  0.5    | -2566.27 |  0.2711 |
# |     1 |  0.6784 | -3780.83 |  0.2597 |
# |     2 |  0.6064 | -4589.14 |  0.2604 |
# |     3 |  0.5872 | -5126.1  |  0.2625 |
# |     4 |  0.5668 | -5571.93 |  0.2654 |

# %% [markdown]
# $\textbf{2.2 Accelerated Function:}$ ```cell_energy```
#
# + ```run_lebwohl_lasher_s_cython.py Version: Commit - a483c7babd1bed483506d98443018aff8e5543b6```

# %%
# Read in the data.
data_compare_002 = pd.DataFrame(np.loadtxt("output_logs/output_seed_42_a483c7babd1bed483506d98443018aff8e5543b6.txt", 
                                             dtype=np.float64, skiprows=9), columns=["MCS", "Ratio", "Energy", "Order"]).set_index("MCS")

print(data_compare_002.head().to_markdown())
# Out:
# |   MCS |   Ratio |   Energy |   Order |
# |------:|--------:|---------:|--------:|
# |     0 |  0.5    | -2566.27 |  0.2711 |
# |     1 |  0.6784 | -3780.83 |  0.2597 |
# |     2 |  0.6064 | -4589.14 |  0.2604 |
# |     3 |  0.5872 | -5126.1  |  0.2625 |
# |     4 |  0.5668 | -5571.93 |  0.2654 |

# %%
# Assert the new version produces data that is consistent.
np.allclose(data_compare_001, data_compare_002)
# Out:
# True

# %% [markdown]
# $\textbf{2.3 Accelerated Function:}$ ```total_energy```
#
# + ```run_lebwohl_lasher_s_cython.py Version: Commit - a13774b66bf82e35d6b38bb6fd737ecbbc2fa16d```

# %%
# Read in the data.
data_compare_003 = pd.DataFrame(np.loadtxt("output_logs/output_seed_42_a13774b66bf82e35d6b38bb6fd737ecbbc2fa16d.txt", 
                                             dtype=np.float64, skiprows=9), columns=["MCS", "Ratio", "Energy", "Order"]).set_index("MCS")

print(data_compare_003.head().to_markdown())
# Out:
# |   MCS |   Ratio |   Energy |   Order |
# |------:|--------:|---------:|--------:|
# |     0 |  0.5    | -2566.27 |  0.2711 |
# |     1 |  0.6784 | -3780.83 |  0.2597 |
# |     2 |  0.6064 | -4589.14 |  0.2604 |
# |     3 |  0.5872 | -5126.1  |  0.2625 |
# |     4 |  0.5668 | -5571.93 |  0.2654 |

# %%
# Assert the new version produces data that is consistent.
np.allclose(data_compare_001, data_compare_003)
# Out:
# True

# %% [markdown]
# $\textbf{2.4 Accelerated Function:}$ ```calculate_order```
#
# + ```run_lebwohl_lasher_s_cython.py Version: Commit - 43ca69be37da6a969c9585b9dc5b5cbb85460c02```

# %%
# Read in the data.
data_compare_004 = pd.DataFrame(np.loadtxt("output_logs/output_seed_42_43ca69be37da6a969c9585b9dc5b5cbb85460c02.txt", 
                                             dtype=np.float64, skiprows=9), columns=["MCS", "Ratio", "Energy", "Order"]).set_index("MCS")

print(data_compare_004.head().to_markdown())
# Out:
# |   MCS |   Ratio |   Energy |   Order |
# |------:|--------:|---------:|--------:|
# |     0 |  0.5    | -2566.27 |  0.2711 |
# |     1 |  0.6784 | -3780.83 |  0.2597 |
# |     2 |  0.6064 | -4589.14 |  0.2604 |
# |     3 |  0.5872 | -5126.1  |  0.2625 |
# |     4 |  0.5668 | -5571.93 |  0.2654 |

# %%
# Assert the new version produces data that is consistent.
np.allclose(data_compare_001, data_compare_004)
# Out:
# True

# %% [markdown]
# $\textbf{2.5 Accelerated Function:}$ ```monte_carlo_step```
#
# + ```run_lebwohl_lasher_s_cython.py Version: Commit - c8be37f204a23e5482934ec4a729b0c58c9c9e5d```

# %%
# Read in the data.
data_compare_005 = pd.DataFrame(np.loadtxt("output_logs/output_seed_42_c8be37f204a23e5482934ec4a729b0c58c9c9e5d.txt", 
                                             dtype=np.float64, skiprows=9), columns=["MCS", "Ratio", "Energy", "Order"]).set_index("MCS")

print(data_compare_005.head().to_markdown())
# Out:
# |   MCS |   Ratio |   Energy |   Order |
# |------:|--------:|---------:|--------:|
# |     0 |  0.5    | -2566.27 |  0.2711 |
# |     1 |  0.6784 | -3780.83 |  0.2597 |
# |     2 |  0.6064 | -4589.14 |  0.2604 |
# |     3 |  0.5872 | -5126.1  |  0.2625 |
# |     4 |  0.5668 | -5571.93 |  0.2654 |

# %%
# Assert the new version produces data that is consistent.
np.allclose(data_compare_001, data_compare_005)
# Out:
# False

# %% [markdown]
# + $\text{At first glance it would seem that this version does not generate consistent values with previous versions.}$
#
# - $\text{However, on closer inspection the same results are produced up until around step 450.}$
# - $\text{The final results being different could be due to floating point imprecision in the compiled script.}$
#
# + $\text{Furthermore, the plots in Section 1 validate the correctness of this version.}$

# %%
# Assert the new version produces data that is consistent (expected false).
np.allclose(data_compare_001.iloc[:450], data_compare_005.iloc[:450])
# Out:
# True

# %% [markdown]
# $\textbf{3. Time Specific Functions}$

# %%
# Import the script.
import run_lebwohl_lasher_s_cython
import lebwohl_lasher_s_cython

# %%
# Generate a lattice.
lattice_length = 50
lattice = run_lebwohl_lasher_s_cython.init_lattice(lattice_length)

# Generate two lattice positions to time the "cell_energy" function.
x_pos, y_pos = np.random.randint(0, high=lattice_length, size=2)

# %% [markdown]
# $\textbf{3.1 Base Version}$
#
# + ```lebwohl_lasher_s_cython.py Version: Commit - 056be5e74a2735b1e6d6625e11b9deed38f00b10```

# %%
# # Time the "cell_energy" function.
# %timeit lebwohl_lasher_s_cython.cell_energy(lattice, lattice_length, x_pos, y_pos)
# Out:
# 7.33 μs ± 514 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# # Time the "total_energy" function.
# %timeit lebwohl_lasher_s_cython.total_energy(lattice, lattice_length)
# Out:
# 17.2 ms ± 964 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# # Time the "calculate_order" function.
# %timeit lebwohl_lasher_s_cython.calculate_order(lattice, lattice_length)
# Out:
# 17.7 ms ± 1.33 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# # Time the "monte_carlo_step" function.
# %timeit lebwohl_lasher_s_cython.monte_carlo_step(lattice, lattice_length, temperature=0.5)
# Out:
# 54.8 ms ± 6.43 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# $\textbf{3.2 Accelerated Function:}$ ```cell_energy```
#
# + ```run_lebwohl_lasher_s_cython.py Version: Commit - a483c7babd1bed483506d98443018aff8e5543b6```

# %%
# # Time the "cell_energy" function.
# %timeit lebwohl_lasher_s_cython.cell_energy(lattice, lattice_length, x_pos, y_pos)
# Out:
# 448 ns ± 10.7 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# $\textbf{3.3 Accelerated Function:}$ ```total_energy```
#
# + ```run_lebwohl_lasher_s_cython.py Version: Commit - a13774b66bf82e35d6b38bb6fd737ecbbc2fa16d```
#
# - $\text{This function was sped up in the previous version because this function relies on the}$ ```cell_energy``` $\text{function.}$
# - $\text{Therefore gains in the overall runtime are not seen in this version of the script.}$

# %%
# # Time the "total_energy" function.
# %timeit lebwohl_lasher_s_cython.total_energy(lattice, lattice_length)
# Out:
# 1.85 ms ± 24.1 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# $\textbf{3.4 Accelerated Function:}$ ```calculate_order```
#
# + ```run_lebwohl_lasher_s_cython.py Version: Commit - 43ca69be37da6a969c9585b9dc5b5cbb85460c02```

# %%
# # Time the "calculate_order" function.
# %timeit lebwohl_lasher_s_cython.calculate_order(lattice, lattice_length)
# Out:
# 61.2 μs ± 1.58 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# $\textbf{3.5 Accelerated Function:}$ ```monte_carlo_step```
#
# + ```run_lebwohl_lasher_s_cython.py Version: Commit - c8be37f204a23e5482934ec4a729b0c58c9c9e5d```

# %%
# Time the "monte_carlo_step" function.
# %timeit lebwohl_lasher_s_cython.monte_carlo_step(lattice, lattice_length, temperature=0.5)
# Out:
# 2.54 ms ± 104 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)
