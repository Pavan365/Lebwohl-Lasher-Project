# %% [markdown]
# $\textbf{Time MPI (NumPy Vectorised) Version}$

# %% [markdown]
# $\textbf{Files Used}$
#
# + ```root/original/lebwohl_lasher_mpi_numpy.py```
#
# $\textbf{Commit Version}$
#
# + ```lebwohl_lasher_mpi_numpy.py - 5ffa0ade8b214e3a0759b49a85277f2be34f794b```

# %%
# Import required libraries.
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# $\textbf{1. BC4 Runtimes}$
#
# + $\text{Lattice Sizes: 25 - 1000}$
#
# - $\text{Monte Carlo Steps: 50}$
# - $\text{Reduced Temperature: 0.5}$

# %% [markdown]
# $\textbf{1.1 Number of Workers - 2}$
#
# + ```python ../statistics.py bc4_workers_02_runtimes mpi_numpy runtimes_workers_02.csv```

# %%
# Read the runtimes into a DataFrame.
runtimes_workers_02 = pd.read_csv("runtimes_workers_02.csv")

# Print the DataFrame.
print(runtimes_workers_02.to_markdown())
# Out:
# |    |   Lattice-Size |   Runtime-Average |   Runtime-STD |
# |---:|---------------:|------------------:|--------------:|
# |  0 |             25 |         0.0474789 |   0.00103614  |
# |  1 |             50 |         0.0886557 |   0.000830042 |
# |  2 |             75 |         0.155302  |   0.00216102  |
# |  3 |            100 |         0.243293  |   0.00259606  |
# |  4 |            200 |         0.837858  |   0.00189635  |
# |  5 |            300 |         1.82838   |   0.00595354  |
# |  6 |            400 |         3.21222   |   0.0285972   |
# |  7 |            500 |         5.02005   |   0.0352563   |
# |  8 |            600 |         7.34855   |   0.037499    |
# |  9 |            700 |        10.085     |   0.0736048   |
# | 10 |            800 |        13.5477    |   0.174685    |
# | 11 |            900 |        15.2446    |   0.179042    |
# | 12 |           1000 |        19.3163    |   0.206409    |

# %% [markdown]
# $\textbf{1.2 Number of Workers - 4}$
#
# + ```python ../statistics.py bc4_workers_04_runtimes mpi_numpy runtimes_workers_04.csv```

# %%
# Read the runtimes into a DataFrame.
runtimes_workers_04 = pd.read_csv("runtimes_workers_04.csv")

# Print the DataFrame.
print(runtimes_workers_04.to_markdown())
# Out:
# |    |   Lattice-Size |   Runtime-Average |   Runtime-STD |
# |---:|---------------:|------------------:|--------------:|
# |  0 |             25 |         0.0408303 |    0.00102663 |
# |  1 |             50 |         0.0639131 |    0.00152864 |
# |  2 |             75 |         0.0976813 |    0.00120891 |
# |  3 |            100 |         0.148376  |    0.00879108 |
# |  4 |            200 |         0.446629  |    0.00383836 |
# |  5 |            300 |         0.955285  |    0.0075143  |
# |  6 |            400 |         1.64717   |    0.00983767 |
# |  7 |            500 |         2.57829   |    0.0276624  |
# |  8 |            600 |         3.70404   |    0.0880616  |
# |  9 |            700 |         5.0629    |    0.0115203  |
# | 10 |            800 |         6.70502   |    0.0615451  |
# | 11 |            900 |         8.32484   |    0.0187611  |
# | 12 |           1000 |        10.4143    |    0.0911327  |

# %% [markdown]
# $\textbf{1.3 Number of Workers - 8}$
#
# + ```python ../statistics.py bc4_workers_08_runtimes mpi_numpy runtimes_workers_08.csv```

# %%
# Read the runtimes into a DataFrame.
runtimes_workers_08 = pd.read_csv("runtimes_workers_08.csv")

# Print the DataFrame.
print(runtimes_workers_08.to_markdown())
# Out:
# |    |   Lattice-Size |   Runtime-Average |   Runtime-STD |
# |---:|---------------:|------------------:|--------------:|
# |  0 |             25 |         0.0519519 |   0.0300604   |
# |  1 |             50 |         0.0551786 |   0.00948321  |
# |  2 |             75 |         0.069575  |   0.000644606 |
# |  3 |            100 |         0.0935613 |   0.000890598 |
# |  4 |            200 |         0.292115  |   0.07414     |
# |  5 |            300 |         0.512602  |   0.00506537  |
# |  6 |            400 |         0.863979  |   0.00673138  |
# |  7 |            500 |         1.31433   |   0.0163922   |
# |  8 |            600 |         1.89249   |   0.00672369  |
# |  9 |            700 |         2.55458   |   0.025034    |
# | 10 |            800 |         3.35947   |   0.0387133   |
# | 11 |            900 |         4.27424   |   0.0248709   |
# | 12 |           1000 |         5.23611   |   0.0424701   |

# %% [markdown]
# $\textbf{1.4 Number of Threads - 12}$
#
# + ```python ../statistics.py bc4_workers_12_runtimes mpi_numpy runtimes_workers_12.csv```

# %%
# Read the runtimes into a DataFrame.
runtimes_workers_12 = pd.read_csv("runtimes_workers_12.csv")

# Print the DataFrame.
print(runtimes_workers_12.to_markdown())
# Out:
# |    |   Lattice-Size |   Runtime-Average |   Runtime-STD |
# |---:|---------------:|------------------:|--------------:|
# |  0 |             25 |         0.105038  |     0.0866175 |
# |  1 |             50 |         0.117523  |     0.0808837 |
# |  2 |             75 |         0.186052  |     0.129577  |
# |  3 |            100 |         0.0959342 |     0.031505  |
# |  4 |            200 |         0.252589  |     0.122489  |
# |  5 |            300 |         0.465538  |     0.0960488 |
# |  6 |            400 |         0.782512  |     0.220531  |
# |  7 |            500 |         1.18308   |     0.256567  |
# |  8 |            600 |         1.31678   |     0.0472061 |
# |  9 |            700 |         1.84317   |     0.141143  |
# | 10 |            800 |         2.37924   |     0.16524   |
# | 11 |            900 |         2.99115   |     0.11113   |
# | 12 |           1000 |         3.92012   |     0.301488  |

# %% [markdown]
# $\textbf{1.5 Number of Threads - 16}$
#
# + ```python ../statistics.py bc4_workers_16_runtimes mpi_numpy runtimes_workers_16.csv```

# %%
# Read the runtimes into a DataFrame.
runtimes_workers_16 = pd.read_csv("runtimes_workers_16.csv")

# Print the DataFrame.
print(runtimes_workers_16.to_markdown())
# Out:
# |    |   Lattice-Size |   Runtime-Average |   Runtime-STD |
# |---:|---------------:|------------------:|--------------:|
# |  0 |             50 |         0.045881  |   0.000747325 |
# |  1 |             75 |         0.0581595 |   0.00163176  |
# |  2 |            100 |         0.0697809 |   0.000680259 |
# |  3 |            200 |         0.159833  |   0.000993678 |
# |  4 |            300 |         0.292761  |   0.00103516  |
# |  5 |            400 |         0.474065  |   0.00264888  |
# |  6 |            500 |         0.709827  |   0.00501071  |
# |  7 |            600 |         0.992389  |   0.0137893   |
# |  8 |            700 |         1.33526   |   0.0268279   |
# |  9 |            800 |         1.74826   |   0.0125494   |
# | 10 |            900 |         2.20014   |   0.0195004   |
# | 11 |           1000 |         2.72895   |   0.0102633   |

# %% [markdown]
# $\textbf{1.6 Number of Workers - 26}$
#
# + ```python ../statistics.py bc4_workers_26_runtimes mpi_numpy runtimes_workers_26.csv```

# %%
# Read the runtimes into a DataFrame.
runtimes_workers_26 = pd.read_csv("runtimes_workers_26.csv")

# Print the DataFrame.
print(runtimes_workers_26.to_markdown())
# Out:
# |    |   Lattice-Size |   Runtime-Average |   Runtime-STD |
# |---:|---------------:|------------------:|--------------:|
# |  0 |             75 |         0.0544849 |   0.0111946   |
# |  1 |            100 |         0.0621659 |   0.00321784  |
# |  2 |            200 |         0.117151  |   0.000796907 |
# |  3 |            300 |         0.213836  |   0.00233713  |
# |  4 |            400 |         0.330717  |   0.00188805  |
# |  5 |            500 |         0.47708   |   0.0045729   |
# |  6 |            600 |         0.649017  |   0.00802251  |
# |  7 |            700 |         0.846845  |   0.00607433  |
# |  8 |            800 |         1.07832   |   0.0104441   |
# |  9 |            900 |         1.39099   |   0.0104832   |
# | 10 |           1000 |         1.71342   |   0.0246297   |

# %% [markdown]
# $\textbf{1.7 Plot Runtimes}$

# %%
##  Plot the runtimes.

fig, ax = plt.subplots()

ax.errorbar(runtimes_workers_02["Lattice-Size"], runtimes_workers_02["Runtime-Average"], runtimes_workers_02["Runtime-STD"], label="Cores 01")
ax.errorbar(runtimes_workers_04["Lattice-Size"], runtimes_workers_04["Runtime-Average"], runtimes_workers_04["Runtime-STD"], label="Cores 02")
ax.errorbar(runtimes_workers_08["Lattice-Size"], runtimes_workers_08["Runtime-Average"], runtimes_workers_08["Runtime-STD"], label="Cores 04")
ax.errorbar(runtimes_workers_12["Lattice-Size"], runtimes_workers_12["Runtime-Average"], runtimes_workers_12["Runtime-STD"], label="Cores 08")
ax.errorbar(runtimes_workers_16["Lattice-Size"], runtimes_workers_16["Runtime-Average"], runtimes_workers_16["Runtime-STD"], label="Cores 12")
ax.errorbar(runtimes_workers_26["Lattice-Size"], runtimes_workers_26["Runtime-Average"], runtimes_workers_26["Runtime-STD"], label="Cores 16")

ax.legend()
ax.grid()

ax.set_title("MPI (NumPy Vectorised) Script")
ax.set_xlabel("Lattice Size")
ax.set_ylabel("Runtime (s)")

plt.show()
